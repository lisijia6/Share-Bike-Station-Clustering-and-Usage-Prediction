# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data_dir = '/content/drive/My Drive/MIE498 Thesis/Share-Bike-Station-Clustering-and-Usage-Prediction/0_Data'

# %%
data_2019Q1 = pd.read_csv("{}/bikeshare2019/2019-Q1.csv".format(data_dir), header=None)
data_2019Q1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,5,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          0               1  ...        8              9
# 0  Trip Id  Trip  Duration  ...  Bike Id      User Type
# 1  4581278            1547  ...     1296  Annual Member
# 2  4581279            1112  ...     2947  Annual Member
# 3  4581280             589  ...     2293  Annual Member
# 4  4581281             259  ...      283  Annual Member
#
# [5 rows x 10 columns]
